# %%
# ======================================================================
# There are 5 questions in this test with increasing difficulty from 1-5
# Please note that the weight of the grade for the question is relative
# to its difficulty. So your Category 1 question will score much less
# than your Category 5 question.
# ======================================================================
#
# Computer Vision with CNNs
#
# For this exercise you will build a cats v dogs classifier
# using the Cats v Dogs dataset from TFDS.
# Be sure to use the final layer as shown 
#     (Dense, 2 neurons, softmax activation)
#
# The testing infrastructre will resize all images to 224x224 
# with 3 bytes of color depth. Make sure your input layer trains
# images to that specification, or the tests will fail.
#
# Make sure your output layer is exactly as specified here, or the 
# tests will fail.

import tensorflow_datasets as tfds
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint

dataset_name = 'cats_vs_dogs'
# dataset = tfds.load(name=dataset_name, split=tfds.Split.TRAIN)
dataset_t = tfds.load(name=dataset_name, split='train[:80%]')
dataset_v = tfds.load(name=dataset_name, split='train[80%:]')

def preprocess(data):
    # YOUR CODE HERE
    x = data['image']
    y = data['label']
    x = tf.cast(x,tf.float32) / 255.0
    x = tf.image.resize(x, size=(224,224))
    return x, y

def solution_model():
    train_dataset = dataset_t.map(preprocess).batch(32)
    valid_dataset = dataset_v.map(preprocess).batch(32)

    model = Sequential([
                        
        tf.keras.layers.Conv2D(64, (3,3), input_shape=(224,224,3), activation='relu'),
        tf.keras.layers.MaxPool2D(2,2),
        tf.keras.layers.Conv2D(64, (3,3),activation='relu'),
        tf.keras.layers.MaxPool2D(2,2),
        tf.keras.layers.Conv2D(128, (3,3),activation='relu'),
        tf.keras.layers.MaxPool2D(2,2),
        tf.keras.layers.Conv2D(128, (3,3),activation='relu'),
        tf.keras.layers.MaxPool2D(2,2),
        tf.keras.layers.Conv2D(256, (3,3),activation='relu'),
        tf.keras.layers.MaxPool2D(2,2),
        tf.keras.layers.Flatten() ,
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dense(128, activation='relu'),
        # YOUR CODE HERE, BUT MAKE SURE YOUR LAST LAYER HAS 2 NEURONS ACTIVATED BY SOFTMAX
        tf.keras.layers.Dense(2, activation='softmax')
    ])
    
    model.compile(loss='sparse_categorical_crossentropy', optimizer='rmsprop', 
                 metrics=['acc'])
    checkpoint_path = "my_checkpoint.ckpt"
    checkpoint = ModelCheckpoint(filepath= checkpoint_path, save_weights_only=True,
                                save_best_only=True, monitor='val_loss', verbose=1)
    model.fit(train_dataset, validation_data=(valid_dataset), epochs=20
             ,callbacks=[checkpoint])
    
    model.load_weights(checkpoint_path)
    
    return model


# Note that you'll need to save your model as a .h5 like this
# This .h5 will be uploaded to the testing infrastructure
# and a score will be returned to you
if __name__ == '__main__':
    model = solution_model()
    model.save("cat3_catsdogs.h5")
# Out:
# Epoch 1/20
# 582/582 [==============================] - 54s 91ms/step - loss: 0.8042 - acc: 0.5335 - val_loss: 0.6544 - val_acc: 0.6094
#
# Epoch 00001: val_loss improved from inf to 0.65442, saving model to my_checkpoint.ckpt
# Epoch 2/20
# 582/582 [==============================] - 53s 91ms/step - loss: 0.5970 - acc: 0.6921 - val_loss: 0.4873 - val_acc: 0.7599
#
# Epoch 00002: val_loss improved from 0.65442 to 0.48733, saving model to my_checkpoint.ckpt
# Epoch 3/20
# 582/582 [==============================] - 53s 91ms/step - loss: 0.4799 - acc: 0.7771 - val_loss: 0.3714 - val_acc: 0.8349
#
# Epoch 00003: val_loss improved from 0.48733 to 0.37139, saving model to my_checkpoint.ckpt
# Epoch 4/20
# 582/582 [==============================] - 52s 90ms/step - loss: 0.3994 - acc: 0.8213 - val_loss: 0.3238 - val_acc: 0.8609
#
# Epoch 00004: val_loss improved from 0.37139 to 0.32380, saving model to my_checkpoint.ckpt
# Epoch 5/20
# 582/582 [==============================] - 52s 90ms/step - loss: 0.3489 - acc: 0.8500 - val_loss: 0.2921 - val_acc: 0.8760
#
# Epoch 00005: val_loss improved from 0.32380 to 0.29207, saving model to my_checkpoint.ckpt
# Epoch 6/20
# 582/582 [==============================] - 52s 90ms/step - loss: 0.3003 - acc: 0.8768 - val_loss: 0.2654 - val_acc: 0.8844
#
# Epoch 00006: val_loss improved from 0.29207 to 0.26535, saving model to my_checkpoint.ckpt
# Epoch 7/20
# 582/582 [==============================] - 52s 89ms/step - loss: 0.2751 - acc: 0.8867 - val_loss: 0.2513 - val_acc: 0.8975
#
# Epoch 00007: val_loss improved from 0.26535 to 0.25127, saving model to my_checkpoint.ckpt
# Epoch 8/20
# 582/582 [==============================] - 52s 89ms/step - loss: 0.2624 - acc: 0.8933 - val_loss: 0.2484 - val_acc: 0.8908
#
# Epoch 00008: val_loss improved from 0.25127 to 0.24840, saving model to my_checkpoint.ckpt
# Epoch 9/20
# 582/582 [==============================] - 52s 89ms/step - loss: 0.2497 - acc: 0.8978 - val_loss: 0.2339 - val_acc: 0.9033
#
# Epoch 00009: val_loss improved from 0.24840 to 0.23395, saving model to my_checkpoint.ckpt
# Epoch 10/20
# 582/582 [==============================] - 52s 90ms/step - loss: 0.2501 - acc: 0.9109 - val_loss: 0.2551 - val_acc: 0.8914
#
# Epoch 00010: val_loss did not improve from 0.23395
# Epoch 11/20
# 582/582 [==============================] - 52s 89ms/step - loss: 0.2532 - acc: 0.9042 - val_loss: 0.2332 - val_acc: 0.9015
#
# Epoch 00011: val_loss improved from 0.23395 to 0.23323, saving model to my_checkpoint.ckpt
# Epoch 12/20
# 582/582 [==============================] - 52s 90ms/step - loss: 0.2730 - acc: 0.9052 - val_loss: 0.2150 - val_acc: 0.9160
#
# Epoch 00012: val_loss improved from 0.23323 to 0.21504, saving model to my_checkpoint.ckpt
# Epoch 13/20
# 582/582 [==============================] - 52s 89ms/step - loss: 0.2415 - acc: 0.9134 - val_loss: 0.2638 - val_acc: 0.8878
#
# Epoch 00013: val_loss did not improve from 0.21504
# Epoch 14/20
# 582/582 [==============================] - 52s 89ms/step - loss: 0.2547 - acc: 0.9050 - val_loss: 0.3618 - val_acc: 0.8852
#
# Epoch 00014: val_loss did not improve from 0.21504
# Epoch 15/20
# 582/582 [==============================] - 52s 90ms/step - loss: 0.3214 - acc: 0.8983 - val_loss: 0.2355 - val_acc: 0.9035
#
# Epoch 00015: val_loss did not improve from 0.21504
# Epoch 16/20
# 582/582 [==============================] - 53s 91ms/step - loss: 0.4922 - acc: 0.8889 - val_loss: 0.2157 - val_acc: 0.9245
#
# Epoch 00016: val_loss did not improve from 0.21504
# Epoch 17/20
# 582/582 [==============================] - 53s 91ms/step - loss: 0.2867 - acc: 0.8959 - val_loss: 0.2309 - val_acc: 0.9058
#
# Epoch 00017: val_loss did not improve from 0.21504
# Epoch 18/20
# 582/582 [==============================] - 53s 92ms/step - loss: 0.2994 - acc: 0.8882 - val_loss: 0.2004 - val_acc: 0.9192
#
# Epoch 00018: val_loss improved from 0.21504 to 0.20041, saving model to my_checkpoint.ckpt
# Epoch 19/20
# 582/582 [==============================] - 52s 90ms/step - loss: 0.2728 - acc: 0.9022 - val_loss: 0.5590 - val_acc: 0.9211
#
# Epoch 00019: val_loss did not improve from 0.20041
# Epoch 20/20
# 582/582 [==============================] - 52s 89ms/step - loss: 0.3540 - acc: 0.8900 - val_loss: 0.2595 - val_acc: 0.8996
#
# Epoch 00020: val_loss did not improve from 0.20041
