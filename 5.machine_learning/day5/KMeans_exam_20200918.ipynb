# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
X, y = make_blobs(n_samples=300, centers=4, cluster_std=0.6, random_state=0)

plt.scatter(X[:,0], X[:,1])
plt.show()

# %%
k = KMeans(n_clusters=4)
k.fit(X)
# Out:
# KMeans(n_clusters=4)

# %%
k.labels_     #모든 데이터 포인트에 대한 클러스터 번호
# Out:
# array([1, 0, 2, 0, 1, 1, 3, 2, 0, 0, 3, 0, 2, 0, 1, 2, 2, 1, 3, 3, 1, 1,
#        2, 3, 3, 2, 1, 2, 3, 2, 0, 0, 2, 0, 0, 0, 0, 0, 3, 1, 2, 3, 2, 2,
#        3, 3, 0, 3, 0, 1, 3, 1, 0, 1, 1, 3, 0, 3, 0, 1, 0, 2, 0, 3, 3, 3,
#        0, 1, 0, 3, 2, 3, 0, 3, 3, 0, 3, 2, 1, 0, 1, 2, 1, 1, 0, 2, 1, 2,
#        0, 0, 2, 1, 0, 3, 3, 2, 1, 1, 2, 3, 0, 1, 0, 1, 2, 1, 1, 2, 0, 2,
#        3, 3, 1, 0, 1, 2, 0, 1, 1, 2, 3, 1, 3, 1, 1, 1, 1, 3, 1, 3, 0, 3,
#        3, 1, 0, 3, 3, 0, 2, 0, 0, 3, 2, 3, 2, 3, 0, 2, 0, 0, 0, 2, 0, 2,
#        1, 3, 0, 3, 1, 2, 0, 2, 2, 1, 2, 3, 3, 2, 1, 2, 2, 0, 1, 2, 3, 0,
#        1, 1, 2, 3, 1, 2, 3, 3, 2, 2, 2, 2, 1, 0, 2, 3, 2, 2, 3, 3, 3, 2,
#        3, 0, 2, 3, 1, 3, 2, 0, 3, 0, 2, 0, 2, 3, 2, 2, 0, 3, 3, 1, 1, 2,
#        0, 1, 1, 3, 1, 3, 2, 0, 0, 2, 2, 0, 2, 1, 3, 2, 1, 3, 0, 3, 1, 2,
#        1, 0, 0, 0, 0, 3, 3, 0, 2, 3, 1, 2, 3, 3, 3, 1, 1, 0, 2, 2, 3, 1,
#        0, 3, 2, 0, 2, 1, 1, 3, 3, 2, 1, 1, 1, 2, 0, 0, 1, 1, 2, 1, 1, 1,
# ...

# %%
k.cluster_centers_    #클러스터 중심
# Out:
# array([[-1.37324398,  7.75368871],
#        [ 1.98258281,  0.86771314],
#        [ 0.94973532,  4.41906906],
#        [-1.58438467,  2.83081263]])

# %%
plt.scatter(X[:,0], X[:,1], c=k.labels_)
center = k.cluster_centers_
plt.scatter(center[:, 0], center[:,1], c='red', s=200, alpha=0.5)
plt.show()

# %%
### predict 예측 
import numpy as np 
new = np.array([[1,1]])
new
# Out:
# array([[1, 1]])

# %%
k.predict(new)
# Out:
# array([1])

# %%
plt.scatter(X[:,0], X[:,1], c=k.labels_)
center = k.cluster_centers_
plt.scatter(center[:, 0], center[:,1], c='red', s=200, alpha=0.5)

for index, c in enumerate(center):
    plt.text(c[0],c[1], index, fontsize=20
             ,horizontalalignment='center',verticalalignment='center')
plt.show()

# %%
k.predict(X) == k.labels_
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
# ...

# %% [markdown]
# ### 선형군집경계

# %%
plt.scatter(X[k.labels_==0][:,0], X[k.labels_ ==0][:,1], label='cluster0')
plt.scatter(X[k.labels_==1][:,0], X[k.labels_ ==1][:,1],label='cluster1')
plt.scatter(X[k.labels_==2][:,0], X[k.labels_ ==2][:,1],label='cluster2')
plt.scatter(X[k.labels_==3][:,0], X[k.labels_ ==3][:,1],label='cluster3')
plt.legend()

# %%
from sklearn.datasets import make_moons

# %%
X, y = make_moons(200, noise=0.05, random_state=0)
plt.scatter(X[:, 0], X[:, 1])
plt.show()

# %%
label = KMeans(2, random_state=0).fit_predict(X)    #학습 + 예측 -> 클러스터번호

# %%
#시각화 
plt.scatter(X[:, 0], X[:, 1], c=label)
plt.show()

# %%
### SpectralClustering 
from sklearn.cluster import SpectralClustering

model = SpectralClustering(n_clusters=2, affinity='nearest_neighbors')
label = model.fit_predict(X)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:236: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"

# %%
#시각화 
plt.scatter(X[:, 0], X[:, 1], c=label)
plt.show()

# %%
import matplotlib.pyplot as plt 
from sklearn.datasets import make_moons
from sklearn.cluster import KMeans
X, y = make_moons(200, noise=0.05, random_state=0)

ks = range(1,10)
inertias = []

for k in ks:
    model = KMeans(n_clusters=k)
    model.fit(X)
    inertias.append(model.inertia_)

plt.plot(ks, inertias, '-o')
plt.xlabel('number of clusters, k')
plt.ylabel('inertia')
plt.xticks(ks)
plt.show()
